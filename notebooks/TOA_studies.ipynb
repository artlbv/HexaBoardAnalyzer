// %%
TFile::Open("../data/hexa1/RUN_290317_1109_new.root")
// Out:
// (TFile *) 0x7fc644090890

// %%
sk2cms->Draw("toa_rise[]:Iteration$","toa_rise > 4","colz"); c1->Draw()
// Out:
// Info in <TCanvas::MakeDefCanvas>:  created default TCanvas with name c1

// %%
sk2cms->Draw("toa_fall[]:Iteration$","toa_fall > 4","colz"); c1->Draw()

// %%
sk2cms->Draw("tot_slow[]:Iteration$","tot_slow > -90","colz"); c1->Draw()

// %%
sk2cms->Draw("tot_fast[]:Iteration$","tot_fast > 4","colz"); c1->Draw()

// %%
sk2cms->Draw("lg[][5][]:Iteration$","roll[5] == 0","colz"); c1->Draw()

// %%
sk2cms->Draw("toa_rise[3][36]:toa_rise[3][35]","toa_rise > 4","colz"); c1->Draw()

// %%
gStyle->enableJSVis();
c1->Draw();
disableJSVis();
// Out:
// input_line_131:2:10: error: no member named 'enableJSVis' in 'TStyle'
//  gStyle->enableJSVis();
//  ~~~~~~  ^
// input_line_131:3:1: error: use of undeclared identifier 'c1'
// c1->Draw();
// ^
// input_line_131:4:1: error: use of undeclared identifier 'disableJSVis'
// disableJSVis();
// ^
