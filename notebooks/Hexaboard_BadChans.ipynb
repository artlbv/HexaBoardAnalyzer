// %%
TFile *_file1 = TFile::Open("data/hexa1/Hexaboard_1_d1_1ms.root");

// %% [markdown]
// # Pedestal of channel 20 on chip 0

// %%
sk2cms->Draw("hg[0][20]","chip == 0 && !roll[0] && event > 0","colz"); c1->Draw(); 
c1->SetCanvasSize(800,600);

// %% [markdown]
// # Pedestal of channel 46 on chip 1

// %%
sk2cms->Draw("hg[0][46]","chip == 1 && !roll[0] && event > 0","colz"); c1->Draw();

// %% [markdown]
// # Pedestal of channel 54 on chip 1

// %%
sk2cms->Draw("hg[0][54]","chip == 1 && !roll[0] && event > 0","colz"); c1->Draw();

// %% [markdown]
// # Pedestal of channel 0 on chip 2

// %%
sk2cms->Draw("hg[0][0]","chip == 2 && !roll[0] && event > 0","colz"); c1->Draw();

// %% [markdown]
// ## Pedestal of channel 2 on chip 2

// %%
sk2cms->Draw("hg[0][2]","chip == 2 && !roll[0] && event > 1","colz"); c1->Draw()

// %% [markdown]
// ## Pedestal of channel 12 on chip 2

// %%
sk2cms->Draw("hg[0][12]","chip == 2 && !roll[0] && event > 1","colz"); c1->Draw()

// %% [markdown]
// ## Pedestal of channel 58 on chip 3

// %%
sk2cms->Draw("hg[0][58]","chip == 3 && !roll[0] && event > 1","colz"); c1->Draw()

// %%
sk2cms->Draw("hg[0][10]:hg[0][46]","chip == 1 && !roll[0] && event > 1","colz"); c1->Draw()
