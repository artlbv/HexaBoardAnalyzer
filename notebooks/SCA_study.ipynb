// %%
//TFile *_file1 = TFile::Open("sk2cms_tree.root")
TFile *_file1 = TFile::Open("data/RUN_290317_1651.root")
//TFile *_file2 = TFile::Open("data/RUN_290317_1738.root")
// Out:
// (TFile *) nullptr
// Error in <TFile::TFile>: file data/RUN_290317_1651.root does not exist

// %%
sk2cms->Draw("roll[]:Iteration$","chip == 0 && event == 1","box"); c1->Draw()
// Out:
// input_line_62:2:3: error: use of undeclared identifier 'sk2cms'
//  (sk2cms->Draw("roll[]:Iteration$", "chip == 0 && event == 1", "box"))
//   ^
// input_line_63:2:3: error: use of undeclared identifier 'c1'
//  (c1->Draw())
//   ^

// %%
sk2cms->Draw("hg:Iteration$","chip == 0 && event == 1","colz"); c1->Draw()
// Out:
// input_line_65:2:3: error: use of undeclared identifier 'sk2cms'
//  (sk2cms->Draw("hg:Iteration$", "chip == 0 && event == 1", "colz"))
//   ^
// input_line_66:2:3: error: use of undeclared identifier 'c1'
//  (c1->Draw())
//   ^

// %%
sk2cms->Draw("roll[]:Iteration$","chip == 0 && event == 2","box"); c1->Draw()
// Out:
// input_line_68:2:3: error: use of undeclared identifier 'sk2cms'
//  (sk2cms->Draw("roll[]:Iteration$", "chip == 0 && event == 2", "box"))
//   ^
// input_line_69:2:3: error: use of undeclared identifier 'c1'
//  (c1->Draw())
//   ^

// %%
sk2cms->Draw("hg:Iteration$","chip == 0 && event == 2","colz"); c1->Draw()
// Out:
// input_line_71:2:3: error: use of undeclared identifier 'sk2cms'
//  (sk2cms->Draw("hg:Iteration$", "chip == 0 && event == 2", "colz"))
//   ^
// input_line_72:2:3: error: use of undeclared identifier 'c1'
//  (c1->Draw())
//   ^

// %%
sk2cms->Draw("roll[]:Iteration$","chip == 0 && event == 3","box"); c1->Draw()
// Out:
// input_line_74:2:3: error: use of undeclared identifier 'sk2cms'
//  (sk2cms->Draw("roll[]:Iteration$", "chip == 0 && event == 3", "box"))
//   ^
// input_line_75:2:3: error: use of undeclared identifier 'c1'
//  (c1->Draw())
//   ^

// %%
sk2cms->Draw("hg:Iteration$","chip == 3 && event == 2","colz"); c1->Draw()
// Out:
// input_line_77:2:3: error: use of undeclared identifier 'sk2cms'
//  (sk2cms->Draw("hg:Iteration$", "chip == 3 && event == 2", "colz"))
//   ^
// input_line_78:2:3: error: use of undeclared identifier 'c1'
//  (c1->Draw())
//   ^

// %%
sk2cms->Draw("hg[0][]:Iteration$+chip*70 >> h(320,0,320,100,150,250)","!roll[0] && event > 0 && event < 8000","colz"); c1->Draw()
// Out:
// input_line_80:2:3: error: use of undeclared identifier 'sk2cms'
//  (sk2cms->Draw("hg[0][]:Iteration$+chip*70 >> h(320,0,320,100,150,250)", "!roll[0] && event > 0 && event < 8000", "colz"))
//   ^
// input_line_81:2:3: error: use of undeclared identifier 'c1'
//  (c1->Draw())
//   ^

// %%
c1->SetCanvasSize(1000,1800);
// Out:
// input_line_83:2:3: error: use of undeclared identifier 'c1'
//  (c1->SetCanvasSize(1000, 1800))
//   ^

// %%
sk2cms->Draw("hg[0][]+chip*70:Iteration$ >> h(84,0,84,600,150,450)","!roll[0] && event > 0 && event < 8000","colz"); c1->Draw()
// Out:
// input_line_85:2:3: error: use of undeclared identifier 'sk2cms'
//  (sk2cms->Draw("hg[0][]+chip*70:Iteration$ >> h(84,0,84,600,150,450)", "!roll[0] && event > 0 && event < 8000", "colz"))
//   ^
// input_line_86:2:3: error: use of undeclared identifier 'c1'
//  (c1->Draw())
//   ^

// %%
sk2cms->Draw("hg[0][]+75*Iteration$:event","!roll[0] && chip == 0 && event > 0 && event < 8000","colz"); c1->Draw()
// Out:
// input_line_88:2:3: error: use of undeclared identifier 'sk2cms'
//  (sk2cms->Draw("hg[0][]+75*Iteration$:event", "!roll[0] && chip == 0 && event > 0 && event < 8000", "colz"))
//   ^
// input_line_89:2:3: error: use of undeclared identifier 'c1'
//  (c1->Draw())
//   ^

// %%
c1->SetCanvasSize(900,6000);
sk2cms->Draw("hg[4][]+50*Iteration$:event >> (8000,0,8000,1750,0,3500)","chip == 1 && !roll[4] && event > 1 && event < 8000 && Iteration$ < 70","p"); c1->Draw()

// %%
c1->SetCanvasSize(900,600);
sk2cms->Draw("hg[0][5]","chip == 3 && !roll[0] && event > 1 && event < 80000","colz"); c1->Draw()

// %%
sk2cms->Draw("hg[12][3]:hg[12][5]","chip == 3 && !roll[12] && event > 1","colz"); c1->Draw()
