// %%
//TFile *_file0 = TFile::Open("data/hexa1/RUN_290317_1651.root");
//TFile *_file1 = TFile::Open("data/hexa2/RUN_020417_1652.root");
//TFile *_file4 = TFile::Open("data/hexa1/Hexaboard_1.root");
TFile *_file1 = TFile::Open("/Users/artur/cernbox/HGCAL/sk2cms/hexaboard_v0/data/hexa1/Hexaboard_1_d1_1ms_new.root");

// %% [markdown]
// # Pedestal of channel 0 on chip 0

// %%
sk2cms->Draw("hg[0][0][0]","!roll[0] && event > 1","colz"); c1->Draw(); c1->SetCanvasSize(800,600);
// Out:
// Info in <TCanvas::MakeDefCanvas>:  created default TCanvas with name c1

// %% [markdown]
// # Pedestal of channel 10 on chip 0

// %%
sk2cms->Draw("hg[0][0][10]","!roll[0] && event > 1","colz"); c1->Draw()

// %% [markdown]
// # Correlation of channels 0 and 10 on chip 0

// %%
sk2cms->Draw("hg[0][0][0]:hg[0][0][10]","!roll[0] && event > 1","colz"); c1->Draw()

// %% [markdown]
// ## Pedestal of channel 43 on chip 0

// %%
sk2cms->Draw("hg[0][0][20]","!roll[0] && event > 1","colz"); c1->Draw()

// %% [markdown]
// # Correlation of channels 0 and 43 on chip 0

// %%
sk2cms->Draw("hg[0][0][0]:hg[0][0][20]","!roll[0] && event > 1","colz"); c1->Draw()

// %% [markdown]
// # Pedestal of channel 0 on chip 2

// %%
sk2cms->Draw("hg[2][0][0]","!roll[0] && event > 1","colz"); c1->Draw()

// %% [markdown]
// ## Pedestal of channel 61 on chip 2

// %%
sk2cms->Draw("hg[2][0][61]","!roll[0] && event > 1","colz"); c1->Draw()

// %% [markdown]
// # Correlation of channels 0 and 1 on chip 2

// %%
sk2cms->Draw("hg[2][0][1]:hg[2][0][0]","!roll[0] && event > 1","colz"); c1->Draw()

// %% [markdown]
// ## Pedestal of channel 0 on chip 2

// %%
sk2cms->Draw("hg[2][0][0]","!roll[0] && event > 1","colz"); c1->Draw()

// %% [markdown]
// # Correlation of channels 0 and 2 on chip 2

// %%
sk2cms->Draw("hg[2][0][2]:hg[2][0][0]","!roll[0] && event > 1","colz"); c1->Draw()

// %%
sk2cms->Draw("hg[0][0][0]:hg[0][0][1]","!roll[0] && event > 1","colz"); c1->Draw()
