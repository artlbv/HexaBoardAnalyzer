// %%
//TFile *_file0 = TFile::Open("data/RUN_290317_1651.root");
//TFile *_file1 = TFile::Open("data/hexa2/RUN_020417_1652.root");
//TFile *_file2 = TFile::Open("data/hexa1/Hexaboard_1_d1_1ms.root");
TFile *_file3 = TFile::Open("data/hexa1/Hexaboard_1_d1_10us.root");

// %% [markdown]
// # Pedestal of channel 0 on chip 0

// %%
sk2cms->Draw("hg[0][0]","chip == 0 && !roll[0] && event > 0","colz"); c1->Draw(); c1->SetCanvasSize(800,600);

// %% [markdown]
// # Pedestal of channel 10 on chip 0

// %%
sk2cms->Draw("hg[0][10]","chip == 0 && !roll[0] && event > 1","colz"); c1->Draw()

// %% [markdown]
// # Correlation of channels 0 and 10 on chip 0

// %%
sk2cms->Draw("hg[0][0]:hg[0][10]","chip == 0 && !roll[0] && event > 1","colz"); c1->Draw()

// %% [markdown]
// ## Pedestal of channel 43 on chip 0

// %%
sk2cms->Draw("hg[0][43]","chip == 0 && !roll[0] && event > 1","colz"); c1->Draw()

// %% [markdown]
// # Correlation of channels 0 and 43 on chip 0

// %%
sk2cms->Draw("hg[0][0]:hg[0][43]","chip == 0 && !roll[0] && event > 1","colz"); c1->Draw()

// %% [markdown]
// # Pedestal of channel 0 on chip 2

// %%
sk2cms->Draw("hg[0][0]","chip == 2 && !roll[0] && event > 1","colz"); c1->Draw()

// %% [markdown]
// ## Pedestal of channel 61 on chip 2

// %%
sk2cms->Draw("hg[0][61]","chip == 2 && !roll[0] && event > 1","colz"); c1->Draw()

// %% [markdown]
// # Correlation of channels 0 and 61 on chip 2

// %%
sk2cms->Draw("hg[0][0]:hg[0][61]","chip == 2 && !roll[0] && event > 1","colz"); c1->Draw()

// %% [markdown]
// ## Pedestal of channel 63 on chip 2

// %%
sk2cms->Draw("hg[0][63]","chip == 2 && !roll[0] && event > 1","colz"); c1->Draw()

// %% [markdown]
// # Correlation of channels 61 and 63 on chip 2

// %%
sk2cms->Draw("hg[0][63]:hg[0][61]","chip == 2 && !roll[0] && event > 1","colz"); c1->Draw()
