# %%
import csv

# %%
fname = "fromDocDB/Skiroc2CMS_sensor_map_simplified.csv"
csvfile = open(fname,"r")

# %%
reader = csv.DictReader(csvfile)

# %%
for row in reader:
    print row#['Sensor Channel']
# Out:
# {'Sensor Channel': '1', 'IC': '0', 'IC Channel': '20'}
# {'Sensor Channel': '2', 'IC': '3', 'IC Channel': '50'}
# {'Sensor Channel': '3', 'IC': '3', 'IC Channel': '48'}
# {'Sensor Channel': '4', 'IC': '3', 'IC Channel': '44'}
# {'Sensor Channel': '5', 'IC': '0', 'IC Channel': '22'}
# {'Sensor Channel': '6', 'IC': '0', 'IC Channel': '12'}
# {'Sensor Channel': '7', 'IC': '3', 'IC Channel': '56'}
# {'Sensor Channel': '8', 'IC': '3', 'IC Channel': '52'}
# {'Sensor Channel': '9', 'IC': '3', 'IC Channel': '36'}
# {'Sensor Channel': '10', 'IC': '3', 'IC Channel': '32'}
# {'Sensor Channel': '11', 'IC': '0', 'IC Channel': '28'}
# {'Sensor Channel': '12', 'IC': '0', 'IC Channel': '24'}
# {'Sensor Channel': '13', 'IC': '0', 'IC Channel': '8'}
# {'Sensor Channel': '14', 'IC': '0', 'IC Channel': '10'}
# {'Sensor Channel': '15', 'IC': '3', 'IC Channel': '46'}
# {'Sensor Channel': '16', 'IC': '3', 'IC Channel': '62'}
# {'Sensor Channel': '17', 'IC': '3', 'IC Channel': '54'}
# ...

# %%
sensor_map = {} # var:[] for var in variabs }

# %%
for chip in range(4):
    sensor_map[chip] = 64 *[-99]
    for chan in range(64):
        if chan % 2 == 0:
            # get sensor position
            sensor_map[chip][chan] = 1

# %%
sensor_map
# Out:
# {0: [1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99],
#  1: [1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
#   1,
#   -99,
# ...
