// %%
//TFile *_file0 = TFile::Open("data/hexa1/Hexaboard_1_1.root")
//TFile *_file2 = TFile::Open("data/hexa2/Hexaboard_2.root")
//TFile *_file1 = TFile::Open("data/hexa1/Hexaboard_1_d1_1ms.root")
TFile *_file3 = TFile::Open("data/hexa1/Hexaboard_1_d1_10us.root");

// %%
sk2cms->Draw("roll[]:Iteration$","chip == 0 && event == 1","box"); c1->Draw()
// Out:
// Info in <TCanvas::MakeDefCanvas>:  created default TCanvas with name c1

// %%
sk2cms->Draw("hg:Iteration$","chip == 0 && event == 1","colz"); c1->Draw()

// %%
sk2cms->Draw("roll[]:Iteration$","chip == 0 && event == 2","box"); c1->Draw()

// %%
sk2cms->Draw("hg:Iteration$","chip == 0 && event == 2","colz"); c1->Draw()

// %%
sk2cms->Draw("roll[]:Iteration$","chip == 0 && event == 3","box"); c1->Draw()

// %%
sk2cms->Draw("hg:Iteration$","chip == 3 && event == 3","colz"); c1->Draw()

// %%
sk2cms->Draw("hg[0][]:Iteration$+chip*70 >> h(320,0,320,100,150,250)","!roll[0] && event > 0","colz"); c1->Draw()

// %%
c1->SetCanvasSize(1000,1800);

// %%
sk2cms->Draw("hg[0][]+chip*70:63-Iteration$ >> h(84,0,84,600,150,450)","!roll[0] && event > 0 && event < 8000","colz"); c1->Draw()

// %%
sk2cms->Draw("hg[0][]+75*Iteration$:event","!roll[0] && chip == 0 && event > 0 && event < 8000","colz"); c1->Draw()

// %%
c1->SetCanvasSize(900,6000);
sk2cms->Draw("hg[4][]+70*Iteration$:event >> (8000,0,8000,2500,0,5000)","chip == 2 && !roll[4] && event > 1 && event < 8000 && Iteration$ < 70","p"); c1->Draw()

// %%
c1->SetCanvasSize(900,600);
sk2cms->Draw("hg[12][62]:event","chip == 2 && !roll[12] && event > 1 && event < 80000","p*"); c1->Draw()

// %%
sk2cms->Draw("hg[12][61]:hg[12][20]","chip == 2 && !roll[12] && event > 1","colz"); c1->Draw()

// %%
sk2cms->Draw("hg[0][61]*hg[0][20]","chip == 0 && !roll[0] && event > 1","colz"); c1->Draw()

// %%
sk2cms->Draw("event","chip == 0 && !roll[0] && event > 1 && (hg[0][61]*hg[0][20] > 42000)","colz"); c1->Draw()

// %%
sk2cms->Draw("hg[0][50]:event","chip == 0 && !roll[0] && event > 1 && event < 5000","p*"); c1->Draw()

// %%
sk2cms->Draw("hg[][50]:Iteration$","chip == 0 && !roll[Iteration$] && event > 0 && event < 1000","colz"); c1->Draw()
