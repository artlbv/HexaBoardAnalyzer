// %%
TFile *_file1 = TFile::Open("/Users/artur/Work/LLR/HGCAL/testbench/results/data/sk2cms/default_ADCconfig/1_minutes_dif_1_1_1.raw.root")
// Out:
// (TFile *) 0x7f8ef5650e70

// %%
sk2cms->Draw("rollpos[]:Iteration$","event == 2","box"); c1->Draw()
// Out:
// Info in <TCanvas::MakeDefCanvas>:  created default TCanvas with name c1

// %%
sk2cms->Draw("charge_hiGain:Iteration$","event == 2","colz"); c1->Draw()

// %%
sk2cms->Draw("rollpos[]:Iteration$","event == 3","box"); c1->Draw()

// %%
sk2cms->Draw("charge_hiGain:Iteration$","event == 2","colz"); c1->Draw()

// %%
sk2cms->Draw("charge_hiGain[4][]:Iteration$","!rollpos[4] && event > 1 && event < 8000","colz"); c1->Draw()

// %%
c1->SetCanvasSize(800,600);
c1->Draw()

// %%
sk2cms->Draw("charge_hiGain[4][]:Iteration$ >> h(84,0,84,100,200,300)","!rollpos[4] && event > 1 && event < 8000","colz"); c1->Draw()

// %%
sk2cms->Draw("charge_hiGain[4][]:event+Entries$*Iteration$","!rollpos[4] && event > 1 && event < 50000 && Iteration$ < 10","colz"); c1->Draw()

// %%
c1->SetCanvasSize(900,6000);

// %%
sk2cms->Draw("charge_hiGain[4][]+50*Iteration$:event >> (12000,0,12000,1750,0,3500)","!rollpos[4] && event > 1 && event < 50000 && Iteration$ < 70","p"); c1->Draw()

// %%
c1->SetCanvasSize(900,600);
sk2cms->Draw("charge_hiGain[12][61]:charge_hiGain[12][63]","!rollpos[12] && event > 1","colz"); c1->Draw()
